# %% [markdown]
# # Hola Mundo - Notebook Completo
#
# Este notebook contiene ejemplos basicos de Python.

# %%
print('¡Hola Mundo!')

# %% [markdown]
# ## Variables y tipos de datos

# %%
# Variables basicas
nombre = 'Python'
edad = 30
altura = 1.75
activo = True

print(f'Nombre: {nombre}')
print(f'Edad: {edad}')
print(f'Altura: {altura}')
print(f'Activo: {activo}')

# %% [markdown]
# ## Operaciones aritmeticas

# %%
a = 10
b = 5

suma = a + b
resta = a - b
multiplicacion = a * b
division = a / b
potencia = a ** b

print(f'Suma: {suma}')
print(f'Resta: {resta}')
print(f'Multiplicacion: {multiplicacion}')
print(f'Division: {division}')
print(f'Potencia: {potencia}')

# %% [markdown]
# ## Listas y bucles

# %%
numeros = [1, 2, 3, 4, 5]
nombres = ['Alice', 'Bob', 'Charlie']

print('Numeros:', numeros)
print('Nombres:', nombres)

for numero in numeros:
    print(f'Numero: {numero}')

# %% [markdown]
# ## Funciones

# %%
def saludar(nombre):
    return f'Hola {nombre}!'

def sumar(a, b):
    return a + b

print(saludar('Mundo'))
print(f'2 + 3 = {sumar(2, 3)}')

# %% [markdown]
# ## Diccionarios

# %%
persona = {
    'nombre': 'Juan',
    'edad': 25,
    'ciudad': 'Madrid',
    'profesion': 'Ingeniero'
}

print('Diccionario persona:')
for clave, valor in persona.items():
    print(f'{clave}: {valor}')
